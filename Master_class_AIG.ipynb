# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas 
import json
def auto_dataframe(data_json):
    data_json = open('new_york_times_bestsellers-clean.json', 'r')
    df = pd.DataFrame.from_dict(data_json)
